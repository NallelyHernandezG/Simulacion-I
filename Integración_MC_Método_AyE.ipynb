# %% [markdown]
# <a href="https://colab.research.google.com/github/NallelyHernandezG/Simulacion-I/blob/main/Integraci%C3%B3n_MC_M%C3%A9todo_AyE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de la función a integrar
def f(x):
    return np.arctan(x)

# Parámetros de la simulación
n_samples = 10000  # Número de muestras
a, b = 0, 1  # Límites de integración
y_min, y_max = 0, np.arctan(1)  # Valores mínimos y máximos de y en el rango [0, 1]

# Generación de muestras aleatorias
x_samples = np.random.uniform(a, b, n_samples)
y_samples = np.random.uniform(y_min, y_max, n_samples)

# Evaluación de los aciertos (puntos bajo la curva)
under_curve = y_samples <= f(x_samples)
hits = np.sum(under_curve)

# Cálculo de la integral mediante el método de acierto y error
area_rect = (b - a) * (y_max - y_min)
integral_estimate = area_rect * (hits / n_samples)

# Resultados
print(f"Estimación de la integral: {integral_estimate:.5f}")

# Gráfica de la función y puntos de muestra
x = np.linspace(a, b, 400)
y = f(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='arctan(x)', color='blue')
plt.scatter(x_samples, y_samples, color='red', s=1, alpha=0.5, label='Puntos bajo la curva' if under_curve.all() else 'Puntos fuera de la curva')
plt.title('Integración de arctan(x) mediante Monte Carlo (Acierto y Error)')
plt.xlabel('x')
plt.ylabel('arctan(x)')
plt.legend()
plt.grid(True)
plt.show()

# Gráfico de los puntos bajo y sobre la curva
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='arctan(x)', color='blue')
plt.scatter(x_samples[under_curve], y_samples[under_curve], color='green', s=1, alpha=0.5, label='Puntos bajo la curva')
plt.scatter(x_samples[~under_curve], y_samples[~under_curve], color='red', s=1, alpha=0.5, label='Puntos fuera de la curva')
plt.title('Puntos bajo y fuera de la curva de arctan(x)')
plt.xlabel('x')
plt.ylabel('arctan(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Estimación de la integral: 0.43692
